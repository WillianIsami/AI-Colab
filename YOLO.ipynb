# %% [markdown]
# <a href="https://colab.research.google.com/github/WillianIsami/YOLO-object-detection/blob/main/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GPU config

# %%
# !nvidia-smi
# Out:
# Sun Apr  2 00:19:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Installing ultralytics to use Yolo

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.3/488.3 KB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 6.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Importing Yolo

# %%
from ultralytics import YOLO

# %% [markdown]
# Testing the detector with the model yolov8n.pt

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="animal2.jpg" save=True
# Out:
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/animal2.jpg: 480x640 1 horse, 18.6ms
# Speed: 0.5ms preprocess, 18.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# Visualization
from IPython.display import Image
Image('/content/runs/detect/predict2/animal2.jpg') #

# %% [markdown]
# Testing the detector with the model yolov8l-seg.pt (segment)

# %%
# !yolo task=detect mode=predict model=yolov8l-seg.pt conf=0.25 source="animal2.jpg" save=True
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45973568 parameters, 0 gradients, 220.5 GFLOPs
#
# image 1/1 /content/animal2.jpg: 480x640 1 horse, 63.5ms
# Speed: 0.7ms preprocess, 63.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict2

# %%
# Visualization
from IPython.display import Image
Image('/content/runs/segment/predict2/animal2.jpg')
